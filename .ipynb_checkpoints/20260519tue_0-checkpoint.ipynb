# %% [markdown]
# <div style="text-align: center; font-size: 24px;">
#   <span style="color: red; font-weight: bold;">[ 퀴즈 1]</span><br>
#   <span style="color: orange; font-weight: bold;">아래와 같은 결과를 만들기 위해 빈 칸에 알맞은 코드를 작성하시오.</span><br>
#   <span style="font-weight: bold;">(주어진 데이터에서 KBS의 시청률이 30이 넘은 데이터만 확인)</span>
# </div>

# %%
import pandas as pd

df = pd.read_csv('broadcast.csv', index_col=0)
df
# Out:
#          KBS     MBC     SBS  TV CHOSUN   JTBC  Channel A    MBN
# 2011  35.951  18.374  11.173      9.102  7.380      3.771  2.809
# 2012  36.163  16.022  11.408      8.785  7.878      5.874  3.310
# 2013  31.989  16.778   9.673      9.026  7.810      5.350  3.825
# 2014  31.210  15.663   9.108      9.440  7.490      5.776  4.572
# 2015  27.777  16.573   9.099      9.940  7.267      6.678  5.520
# 2016  27.583  14.982   8.669      9.829  7.727      6.624  5.477
# 2017  26.890  12.465   8.661      8.886  9.453      6.056  5.215

# %%
df['KBS'] > 30 # KBS 에서 시청률이 30보다 큰 값 검색 - Series
# Out:
# 2011     True
# 2012     True
# 2013     True
# 2014     True
# 2015    False
# 2016    False
# 2017    False
# Name: KBS, dtype: bool

# %%
df.loc[df['KBS'] > 30, 'KBS'] # KBS 에서 시청률이 30보다 큰 값 검색(인덱싱) - Series
# Out:
# 2011    35.951
# 2012    36.163
# 2013    31.989
# 2014    31.210
# Name: KBS, dtype: float64

# %%
df.loc[df['KBS'] > 30, ['KBS']] # KBS 에서 시청률이 30보다 큰 값 검색(인덱싱) - DataFrame
# Out:
#          KBS
# 2011  35.951
# 2012  36.163
# 2013  31.989
# 2014  31.210

# %%
df[['KBS']].loc[df['KBS'] > 30] # KBS 에서 시청률이 30보다 큰 값 검색 - DataFrame (loc 즉 로케이션 명령어 없는 버전) (같은 결과지만 처리 속도가 빠름)
# Out:
#          KBS
# 2011  35.951
# 2012  36.163
# 2013  31.989
# 2014  31.210

# %% [markdown]
# # **[20260421 Tue] - 오늘 수업 종료(2교시).**

# %% [markdown]
# # **[20260422 Wed] - 오늘 수업 시작(5교시).**

# %% [markdown]
# <div style="text-align: center; font-size: 24px;">
#   <span style="color: red; font-weight: bold;">[ 퀴즈 2]</span><br>
#   <span style="color: orange; font-weight: bold;">아래와 같은 결과를 만들기 위해 빈 칸에 알맞은 코드를 작성하시오.</span><br>
#   <span style="font-weight: bold;">주어진 데이터에서 SBS가 TV CHOSUN보다 더 시청률이 낮았던 시기의 데이터를 확인</span>
# </div>

# %%
import pandas as pd

df = pd.read_csv('broadcast.csv', index_col=0)
df
# Out:
#          KBS     MBC     SBS  TV CHOSUN   JTBC  Channel A    MBN
# 2011  35.951  18.374  11.173      9.102  7.380      3.771  2.809
# 2012  36.163  16.022  11.408      8.785  7.878      5.874  3.310
# 2013  31.989  16.778   9.673      9.026  7.810      5.350  3.825
# 2014  31.210  15.663   9.108      9.440  7.490      5.776  4.572
# 2015  27.777  16.573   9.099      9.940  7.267      6.678  5.520
# 2016  27.583  14.982   8.669      9.829  7.727      6.624  5.477
# 2017  26.890  12.465   8.661      8.886  9.453      6.056  5.215

# %%
df['SBS'] > 10 # SBS가 TV CHOSUN보다 시청률이 낮은 값 검색 - Series
# Out:
# 2011     True
# 2012     True
# 2013    False
# 2014    False
# 2015    False
# 2016    False
# 2017    False
# Name: SBS, dtype: bool

# %%
# SBS가 TV CHOSUN보다 시청률이 낮은 값 검색 - Series
# 코드 공석

# %%
# SBS가 TV CHOSUN보다 시청률이 낮은 값 검색 - Dataframe
# 코드 공석

# %%
df.loc[df['SBS'] > 30, 'TV CHOSUN'] # ?
# Out:
# Series([], Name: TV CHOSUN, dtype: float64)

# %% [markdown]
# ### **정정 코드?** (챗GPT)

# %%
df['SBS'][df['SBS'] < df['TV CHOSUN']]
# Out:
# 2014    9.108
# 2015    9.099
# 2016    8.669
# 2017    8.661
# Name: SBS, dtype: float64

# %%
df[df['SBS'] < df['TV CHOSUN']]
# Out:
#          KBS     MBC    SBS  TV CHOSUN   JTBC  Channel A    MBN
# 2014  31.210  15.663  9.108      9.440  7.490      5.776  4.572
# 2015  27.777  16.573  9.099      9.940  7.267      6.678  5.520
# 2016  27.583  14.982  8.669      9.829  7.727      6.624  5.477
# 2017  26.890  12.465  8.661      8.886  9.453      6.056  5.215

# %% [markdown]
# #### **뽀너스**) (인덱스까지 뽑고 싶으면)

# %%
df.index[df['SBS'] < df['TV CHOSUN']]
# Out:
# Index([2014, 2015, 2016, 2017], dtype='int64')

# %% [markdown]
# ### 여기서부터 다시 **Teacher**

# %%
# SBS 시청률
df['SBS']
# Out:
# 2011    11.173
# 2012    11.408
# 2013     9.673
# 2014     9.108
# 2015     9.099
# 2016     8.669
# 2017     8.661
# Name: SBS, dtype: float64

# %%
# 두 방송사 시청률 비교하는 조건식 만들기
df['SBS'] < df['TV CHOSUN']
# Out:
# 2011    False
# 2012    False
# 2013    False
# 2014     True
# 2015     True
# 2016     True
# 2017     True
# dtype: bool

# %%
# 데이터프레임으로 조건식 반영
df.loc[df['SBS'] < df['TV CHOSUN']]
# Out:
#          KBS     MBC    SBS  TV CHOSUN   JTBC  Channel A    MBN
# 2014  31.210  15.663  9.108      9.440  7.490      5.776  4.572
# 2015  27.777  16.573  9.099      9.940  7.267      6.678  5.520
# 2016  27.583  14.982  8.669      9.829  7.727      6.624  5.477
# 2017  26.890  12.465  8.661      8.886  9.453      6.056  5.215

# %%
# SBS 가 TV CHOSUN 보다 시청률이 낮았던 시기의 두 방송사 시청률(데이터프레임)
df.loc[df['SBS'] < df['TV CHOSUN'], ['SBS', 'TV CHOSUN']]
# Out:
#         SBS  TV CHOSUN
# 2014  9.108      9.440
# 2015  9.099      9.940
# 2016  8.669      9.829
# 2017  8.661      8.886

# %% [markdown]
# # **[20260422 Wed] - 오늘 수업 종료(5교시).**

# %% [markdown]
# # **[20260428 Wed] - 오늘 수업 시작(1교시).**

# %% [markdown]
# ### **csv파일에서 여러가지 값 가져오기(Boolean List)**

# %%
import pandas as pd

# %%
iphone_df = pd.read_csv('iphone.csv', index_col=0)
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
# Boolean List(True, False)를 이용해서 인덱싱하기 - 인덱스의 개수에 주의!

# %%
iphone_df.loc[[True, False, True, False, True, False, True]]
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
# Boolean List(True, False)를 이용해서 필터링하기 - 컬럼의 개수에 주의!

# %%
iphone_df.loc[:, [True, False, True, False, True]]
# Out:
#                       출시일  메모리 Face ID
# iPhone 7       2016-09-16  2GB      No
# iPhone 7 Plus  2016-09-16  3GB      No
# iPhone 8       2017-09-22  2GB      No
# iPhone 8 Plus  2017-09-22  3GB      No
# iPhone X       2017-11-03  3GB     Yes
# iPhone XS      2018-09-21  4GB     Yes
# iPhone XS Max  2018-09-21  4GB     Yes

# %% [markdown]
# ### **실제로 위의 예제와 같이 사용할 일은 극히 적다!**
# ### **주로 사용하게 되는 상황은...**

# %% [markdown]
# ### **1. 디스플레이 크기가 5보다 큰 제품 검색**

# %%
# 각 제품의 디스플레이 값 조회

# %%
iphone_df[['디스플레이']] > 5
# Out:
#                디스플레이
# iPhone 7       False
# iPhone 7 Plus   True
# iPhone 8       False
# iPhone 8 Plus   True
# iPhone X        True
# iPhone XS       True
# iPhone XS Max   True

# %%
# 11쪽

# 디스플레이 크기가 5보다 큰 제품 조회 - Series

# %%
iphone_df['디스플레이'] > 5
# Out:
# iPhone 7         False
# iPhone 7 Plus     True
# iPhone 8         False
# iPhone 8 Plus     True
# iPhone X          True
# iPhone XS         True
# iPhone XS Max     True
# Name: 디스플레이, dtype: bool

# %%
# 위 결과값의 타입 확인

# %%
type(iphone_df['디스플레이']>5)
# Out:
# pandas.core.series.Series

# %%
# 디스플레이 크기가 5보다 큰 제품 인덱싱 - DataFrame

# %%
iphone_df.loc[iphone_df['디스플레이']>5]
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
# 위 결과값의 타입 확인

# %%
type(iphone_df.loc[iphone_df['디스플레이']>5])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### **2. Face ID가 되는 기종 검색**

# %%
# 각 제품의 Face ID 값 조회

# %%
# Face ID가 되는 제품 조회 - Series

# %%
iphone_df['Face ID'] == 'Yes'
# Out:
# iPhone 7         False
# iPhone 7 Plus    False
# iPhone 8         False
# iPhone 8 Plus    False
# iPhone X          True
# iPhone XS         True
# iPhone XS Max     True
# Name: Face ID, dtype: bool

# %%
# Face ID가 되는 제품 인덱싱 - DataFrame

# %%
iphone_df.loc[iphone_df['Face ID']=='Yes']
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
# 12쪽은 다시 복습 실습해보기 생략. 워크스페이스에 12쪽 내용을 했던 파일이 아마도 분명히 저장되어 있을 것.

# %%
# 15쪽 슬라이싱

# %% [markdown]
# ### **8. Slicing(슬라이싱)의 다양한 활용**

# %%
# 1차원 배열 Days 설정

# %%
Days = ['월','화','수','목','금','토','일']

# %%
# Days의 첫번째 값 가져오기

# %%
Days[1]
# Out:
# '화'

# %%
Days[0:5]
# Out:
# ['월', '화', '수', '목', '금']

# %%
Days[:5]
# Out:
# ['월', '화', '수', '목', '금']

# %%
Days[5:7]
# Out:
# ['토', '일']

# %%
Days[5:]
# Out:
# ['토', '일']

# %%
Days[1:1]
# Out:
# []

# %%
Days[1:0]
# Out:
# []

# %%
Days[0:1]
# Out:
# ['월']

# %%
Days[4:-1]
# Out:
# ['금', '토']

# %%
Days[1:6:2]
# Out:
# ['화', '목', '토']

# %%
Days[0:5:2]
# Out:
# ['월', '수', '금']

# %%
Days[2:7:2]
# Out:
# ['수', '금', '일']

# %%
Days[2::2]
# Out:
# ['수', '금', '일']

# %%
Days[0:7:2]
# Out:
# ['월', '수', '금', '일']

# %%
Days[:7:2]
# Out:
# ['월', '수', '금', '일']

# %%
Days[::2]
# Out:
# ['월', '수', '금', '일']

# %%
Days[0:7:1]
# Out:
# ['월', '화', '수', '목', '금', '토', '일']

# %%
Days[0:7]
# Out:
# ['월', '화', '수', '목', '금', '토', '일']

# %%
Days[:]
# Out:
# ['월', '화', '수', '목', '금', '토', '일']

# %%
Days[7:0:-1] # 내려가는
# Out:
# ['일', '토', '금', '목', '수', '화']

# %%
Days[6:0:-1]
# Out:
# ['일', '토', '금', '목', '수', '화']

# %%
Days[6:0:-1]
# Out:
# ['일', '토', '금', '목', '수', '화']

# %%
Days[6::-1]
# Out:
# ['일', '토', '금', '목', '수', '화', '월']

# %%
Days[::-1]
# Out:
# ['일', '토', '금', '목', '수', '화', '월']

# %% [markdown]
# # **[20260428 Tue] - 오늘 수업 종료(2교시).**

# %% [markdown]
# # **[20260429 Wed] - 오늘 수업 시작(5교시).**

# %% [markdown]
# ### **데이터프레임 인덱스 수업(p17-18)**

# %%
import pandas as pd

# %%
iphone_df = pd.read_csv('iphone.csv', index_col = 0)
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %% [markdown]
# #### 코드형식 예
# ```python
# iphone_df.loc[인덱스, 컬럼]

# %%
iphone_df.loc[['iPhone 8', 'iPhone X']]
# Out:
#                  출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 8  2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone X  2017-11-03    5.8  3GB  iOS 11.1     Yes

# %%
iphone_df.iloc[[2, 4]] #컬럼대신 인덱스로
# Out:
#                  출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 8  2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone X  2017-11-03    5.8  3GB  iOS 11.1     Yes

# %%
iphone_df.loc['iPhone X', '출시일']
# Out:
# '2017-11-03'

# %%
iphone_df.iloc[4, 0]
# Out:
# '2017-11-03'

# %%
# iPhone 7 Plus과 iPhone 8 Plus의 디스플레이, Face ID 값 조회하기(loc)

# %%
iphone_df.loc[['iPhone 7 Plus', 'iPhone 8 Plus'], ['디스플레이', 'Face ID']]
# Out:
#                디스플레이 Face ID
# iPhone 7 Plus    5.5      No
# iPhone 8 Plus    5.5      No

# %%
iphone_df.iloc[[1, 3], [1, 4]]
# Out:
#                디스플레이 Face ID
# iPhone 7 Plus    5.5      No
# iPhone 8 Plus    5.5      No

# %% [markdown]
# ### iPhone X부터 iPhone XS Max 까지의 출시일부터 메모리 값 슬라이싱으로(:) 조회하기(loc) 및 (iloc)

# %%
iphone_df.iloc[4:7, 0:3]
# Out:
#                       출시일  디스플레이  메모리
# iPhone X       2017-11-03    5.8  3GB
# iPhone XS      2018-09-21    5.8  4GB
# iPhone XS Max  2018-09-21    6.5  4GB

# %%
iphone_df.iloc[4:, :3]
# Out:
#                       출시일  디스플레이  메모리
# iPhone X       2017-11-03    5.8  3GB
# iPhone XS      2018-09-21    5.8  4GB
# iPhone XS Max  2018-09-21    6.5  4GB

# %% [markdown]
# # **[20260429 Wed] - 오늘 수업 종료(5교시).**
# #### **loc와(컬럼방식) iloc(인덱스방식)** 크게 이렇게 2가지 함.

# %% [markdown]
# # **[20260512 Mon] - 오늘 수업 시작(1교시).**

# %%
import pandas as pd

# %%
iphone_df = pd.read_csv('iphone.csv', index_col=0)

# %%
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df.loc['iPhone 8', '메모리']
# Out:
# '2GB'

# %% [markdown]
# #### **DF 데이터 변경하기**

# %%
iphone_df.loc['iPhone 8', '메모리'] = '2.5GB'
iphone_df
# Out:
#                       출시일  디스플레이    메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7    2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5    3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2.5GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5    3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8    3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8    4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5    4GB  iOS 12.0     Yes

# %%
iphone_df.loc['iPhone 8', '출시 버전'] = 'iOS 10.3'
iphone_df
# Out:
#                       출시일  디스플레이    메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7    2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5    3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2.5GB  iOS 10.3      No
# iPhone 8 Plus  2017-09-22    5.5    3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8    3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8    4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5    4GB  iOS 12.0     Yes

# %%
iphone_df.loc['iPhone 8'] #전체컬럼출력
# Out:
# 출시일        2017-09-22
# 디스플레이             4.7
# 메모리             2.5GB
# 출시 버전        iOS 10.3
# Face ID            No
# Name: iPhone 8, dtype: object

# %%
iphone_df.loc['iPhone 8'] = ['2016-09-22', '4-7', '2GB', 'iOS 11.0', 'No']
iphone_df
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10888\3034935295.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4-7' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   iphone_df.loc['iPhone 8'] = ['2016-09-22', '4-7', '2GB', 'iOS 11.0', 'No']
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0      No
# iPhone 8       2016-09-22   4-7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03   5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21   5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21   6.5  4GB  iOS 12.0     Yes

# %%
iphone_df.loc[:,'디스플레이']
# Out:
# iPhone 7         4.7
# iPhone 7 Plus    5.5
# iPhone 8         4-7
# iPhone 8 Plus    5.5
# iPhone X         5.8
# iPhone XS        5.8
# iPhone XS Max    6.5
# Name: 디스플레이, dtype: object

# %%
iphone_df['디스플레이']
# Out:
# iPhone 7         4.7
# iPhone 7 Plus    5.5
# iPhone 8         4-7
# iPhone 8 Plus    5.5
# iPhone X         5.8
# iPhone XS        5.8
# iPhone XS Max    6.5
# Name: 디스플레이, dtype: object

# %%
iphone_df['디스플레이'] = ['4.7in','5.5in','4.7in','5.5in','5.8in','5.8in','6.5in', ]
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16  4.7in  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16  5.5in  3GB  iOS 10.0      No
# iPhone 8       2016-09-22  4.7in  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22  5.5in  3GB  iOS 11.0      No
# iPhone X       2017-11-03  5.8in  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21  5.8in  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21  6.5in  4GB  iOS 12.0     Yes

# %%
iphone_df['Face ID']
# Out:
# iPhone 7          No
# iPhone 7 Plus     No
# iPhone 8          No
# iPhone 8 Plus     No
# iPhone X         Yes
# iPhone XS        Yes
# iPhone XS Max    Yes
# Name: Face ID, dtype: object

# %%
iphone_df['Face ID'] = ['No', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO']
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16  4.7in  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16  5.5in  3GB  iOS 10.0      NO
# iPhone 8       2016-09-22  4.7in  2GB  iOS 11.0      NO
# iPhone 8 Plus  2017-09-22  5.5in  3GB  iOS 11.0      NO
# iPhone X       2017-11-03  5.8in  3GB  iOS 11.1      NO
# iPhone XS      2018-09-21  5.8in  4GB  iOS 12.0      NO
# iPhone XS Max  2018-09-21  6.5in  4GB  iOS 12.0      NO

# %%
iphone_df['Face ID'] = 'Yes'
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16  4.7in  2GB  iOS 10.0     Yes
# iPhone 7 Plus  2016-09-16  5.5in  3GB  iOS 10.0     Yes
# iPhone 8       2016-09-22  4.7in  2GB  iOS 11.0     Yes
# iPhone 8 Plus  2017-09-22  5.5in  3GB  iOS 11.0     Yes
# iPhone X       2017-11-03  5.8in  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21  5.8in  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21  6.5in  4GB  iOS 12.0     Yes

# %% [markdown]
# # **[20260513 Wed] - 오늘 수업 시작(5교시).**

# %%
import pandas as pd

# %%
iphone_df =pd.read_csv('iphone.csv', index_col=0)
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %% [markdown]
# ### **여러 열(컬럼)의 전체 값 변경하기**

# %%
iphone_df[['디스플레이', 'Face ID']]
# Out:
#                디스플레이 Face ID
# iPhone 7         4.7      No
# iPhone 7 Plus    5.5      No
# iPhone 8         4.7      No
# iPhone 8 Plus    5.5      No
# iPhone X         5.8     Yes
# iPhone XS        5.8     Yes
# iPhone XS Max    6.5     Yes

# %%
iphone_df[['디스플레이', 'Face ID']] = 'X' # 다 X가 됨.
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16     X  2GB  iOS 10.0       X
# iPhone 7 Plus  2016-09-16     X  3GB  iOS 10.0       X
# iPhone 8       2017-09-22     X  2GB  iOS 11.0       X
# iPhone 8 Plus  2017-09-22     X  3GB  iOS 11.0       X
# iPhone X       2017-11-03     X  3GB  iOS 11.1       X
# iPhone XS      2018-09-21     X  4GB  iOS 12.0       X
# iPhone XS Max  2018-09-21     X  4GB  iOS 12.0       X

# %% [markdown]
# ### **여러 행(인덱스)의 전체 값 변경하기**

# %%
iphone_df.loc[['iPhone 7','iPhone X']]
# Out:
#                  출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7  2016-09-16     X  2GB  iOS 10.0       X
# iPhone X  2017-11-03     X  3GB  iOS 11.1       X

# %%
iphone_df.loc[['iPhone 7','iPhone X']] = 'O'
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7                O     O    O         O       O
# iPhone 7 Plus  2016-09-16     X  3GB  iOS 10.0       X
# iPhone 8       2017-09-22     X  2GB  iOS 11.0       X
# iPhone 8 Plus  2017-09-22     X  3GB  iOS 11.0       X
# iPhone X                O     O    O         O       O
# iPhone XS      2018-09-21     X  4GB  iOS 12.0       X
# iPhone XS Max  2018-09-21     X  4GB  iOS 12.0       X

# %% [markdown]
# ### **모든 행(인덱스)와 열(컬럼)값을 변경하기**

# %%
iphone_df[:] #모든컬럼 출력
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7                O     O    O         O       O
# iPhone 7 Plus  2016-09-16     X  3GB  iOS 10.0       X
# iPhone 8       2017-09-22     X  2GB  iOS 11.0       X
# iPhone 8 Plus  2017-09-22     X  3GB  iOS 11.0       X
# iPhone X                O     O    O         O       O
# iPhone XS      2018-09-21     X  4GB  iOS 12.0       X
# iPhone XS Max  2018-09-21     X  4GB  iOS 12.0       X

# %%
#iphone_df[:] = 'X'
#iphone_DF

# %%
iphone_df[:] = 'X'
iphone_df
# Out:
#               출시일 디스플레이 메모리 출시 버전 Face ID
# iPhone 7        X     X   X     X       X
# iPhone 7 Plus   X     X   X     X       X
# iPhone 8        X     X   X     X       X
# iPhone 8 Plus   X     X   X     X       X
# iPhone X        X     X   X     X       X
# iPhone XS       X     X   X     X       X
# iPhone XS Max   X     X   X     X       X

# %%
iphone_df.loc['iPhone 7 Plus':'iPhone XS', '디스플레이':'출시 버전']
# Out:
#               디스플레이 메모리 출시 버전
# iPhone 7 Plus     X   X     X
# iPhone 8          X   X     X
# iPhone 8 Plus     X   X     X
# iPhone X          X   X     X
# iPhone XS         X   X     X

# %%
iphone_df.loc['iPhone 7 Plus':'iPhone XS', '디스플레이':'출시 버전'] = 'O'
iphone_df
# Out:
#               출시일 디스플레이 메모리 출시 버전 Face ID
# iPhone 7        X     X   X     X       X
# iPhone 7 Plus   X     O   O     O       X
# iPhone 8        X     O   O     O       X
# iPhone 8 Plus   X     O   O     O       X
# iPhone X        X     O   O     O       X
# iPhone XS       X     O   O     O       X
# iPhone XS Max   X     X   X     X       X

# %% [markdown]
# ### **특정 조건에 맞는 값만 변경하기**

# %%
import pandas as pd

df = pd.read_csv('broadcast.csv', index_col=0)
df
# Out:
#          KBS     MBC     SBS  TV CHOSUN   JTBC  Channel A    MBN
# 2011  35.951  18.374  11.173      9.102  7.380      3.771  2.809
# 2012  36.163  16.022  11.408      8.785  7.878      5.874  3.310
# 2013  31.989  16.778   9.673      9.026  7.810      5.350  3.825
# 2014  31.210  15.663   9.108      9.440  7.490      5.776  4.572
# 2015  27.777  16.573   9.099      9.940  7.267      6.678  5.520
# 2016  27.583  14.982   8.669      9.829  7.727      6.624  5.477
# 2017  26.890  12.465   8.661      8.886  9.453      6.056  5.215

# %%
iphone_df['디스플레이']
# Out:
# iPhone 7         X
# iPhone 7 Plus    O
# iPhone 8         O
# iPhone 8 Plus    O
# iPhone X         O
# iPhone XS        O
# iPhone XS Max    X
# Name: 디스플레이, dtype: object

# %%
iphone_df['디스플레이']
# Out:
# iPhone 7         X
# iPhone 7 Plus    O
# iPhone 8         O
# iPhone 8 Plus    O
# iPhone X         O
# iPhone XS        O
# iPhone XS Max    X
# Name: 디스플레이, dtype: object

# %%
#iphone_df.loc[iphone_df['디스플레이'] > 5, '디스플레이'] = 'P'
#iphone_df

# %%
iphone_df[['Face ID']]
# Out:
#               Face ID
# iPhone 7            X
# iPhone 7 Plus       X
# iPhone 8            X
# iPhone 8 Plus       X
# iPhone X            X
# iPhone XS           X
# iPhone XS Max       X

# %%
iphone_df[['Face ID']] == 'Yes'
# Out:
#                Face ID
# iPhone 7         False
# iPhone 7 Plus    False
# iPhone 8         False
# iPhone 8 Plus    False
# iPhone X         False
# iPhone XS        False
# iPhone XS Max    False

# %%
iphone_df['Face ID'] == 'No'
# Out:
# iPhone 7         False
# iPhone 7 Plus    False
# iPhone 8         False
# iPhone 8 Plus    False
# iPhone X         False
# iPhone XS        False
# iPhone XS Max    False
# Name: Face ID, dtype: bool

# %%
iphone_df.loc[iphone_df['Face ID'] == 'No', 'Face ID'] = 'no'
iphone_df
# Out:
#               출시일 디스플레이 메모리 출시 버전 Face ID
# iPhone 7        X     X   X     X       X
# iPhone 7 Plus   X     O   O     O       X
# iPhone 8        X     O   O     O       X
# iPhone 8 Plus   X     O   O     O       X
# iPhone X        X     O   O     O       X
# iPhone XS       X     O   O     O       X
# iPhone XS Max   X     X   X     X       X

# %% [markdown]
# # **[20260519 Tue] - 오늘 수업 시작(1교시).**

# %% [markdown]
# **지난 시간 p24 까지 함.**

# %% [markdown]
# **출시일이 2017-01-01 이후인지 확인하기**

# %%
iphone_df['출시일'] > '2017-01-01'
# Out:
# iPhone 7         False
# iPhone 7 Plus    False
# iPhone 8          True
# iPhone 8 Plus     True
# iPhone X          True
# iPhone XS         True
# iPhone XS Max     True
# Name: 출시일, dtype: bool

# %% [markdown]
# **Face ID가 YES인지 확인하기**

# %%
iphone_df[['Face ID']] == 'Yes'
# Out:
#                Face ID
# iPhone 7         False
# iPhone 7 Plus    False
# iPhone 8         False
# iPhone 8 Plus    False
# iPhone X          True
# iPhone XS         True
# iPhone XS Max     True

# %% [markdown]
# **위 두 조건 모두 만족하는 제품 확인하기**

# %% [markdown]
# **위 두 조건 모두 만족하는 제품의 모든 값 확인하기**

# %% [markdown]
# **위 두 조건 모두 만족하는 제품의 모든 값을 V로 변경하기**

# %%
iphone_df[(iphone_df['출시일'] > '2017-01-01') & (iphone_df['Face ID'] == 'Yes')] = 'V'
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22   4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0      No
# iPhone X                V     V    V         V       V
# iPhone XS               V     V    V         V       V
# iPhone XS Max           V     V    V         V       V

# %% [markdown]
# ### **p26**

# %%
import pandas as pd

iphone_df =pd.read_csv('iphone.csv', index_col=0)
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df.loc['iPhone X'] = ['2017-0`-01', '5.0', '4GB', 'iOS 11.1.1', 'Yes']
iphone_df
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_3328\2578263573.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '5.0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   iphone_df.loc['iPhone X'] = ['2017-0`-01', '5.0', '4GB', 'iOS 11.1.1', 'Yes']
#                       출시일 디스플레이  메모리       출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB    iOS 10.0      No
# iPhone 7 Plus  2016-09-16   5.5  3GB    iOS 10.0      No
# iPhone 8       2017-09-22   4.7  2GB    iOS 11.0      No
# iPhone 8 Plus  2017-09-22   5.5  3GB    iOS 11.0      No
# iPhone X       2017-0`-01   5.0  4GB  iOS 11.1.1     Yes
# iPhone XS      2018-09-21   5.8  4GB    iOS 12.0     Yes
# iPhone XS Max  2018-09-21   6.5  4GB    iOS 12.0     Yes

# %%
iphone_df['제조사'] = 'Apple'
iphone_df
# Out:
#                       출시일 디스플레이  메모리       출시 버전 Face ID    제조사
# iPhone 7       2016-09-16   4.7  2GB    iOS 10.0      No  Apple
# iPhone 7 Plus  2016-09-16   5.5  3GB    iOS 10.0      No  Apple
# iPhone 8       2017-09-22   4.7  2GB    iOS 11.0      No  Apple
# iPhone 8 Plus  2017-09-22   5.5  3GB    iOS 11.0      No  Apple
# iPhone X       2017-0`-01   5.0  4GB  iOS 11.1.1     Yes  Apple
# iPhone XS      2018-09-21   5.8  4GB    iOS 12.0     Yes  Apple
# iPhone XS Max  2018-09-21   6.5  4GB    iOS 12.0     Yes  Apple

# %% [markdown]
# **1교시는 여기서 끝**
